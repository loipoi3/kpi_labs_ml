# %%
import numpy as np
from sklearn.neural_network import MLPRegressor
import pandas as pd

# %%
class CustomMLPRegressor:
    def __init__(self, learning_rate=0.01, num_epochs=100, hidden_layer_sizes=(100,)):
        self.learning_rate = learning_rate
        self.num_epochs = num_epochs
        self.hidden_layer_sizes = hidden_layer_sizes
        
    def fit(self, X, y):
        X = np.array(X)
        y = np.array(y)
        self._w = []
        self._b = []
        
        for layer_idx in range(len(self.hidden_layer_sizes)):
            if layer_idx == 0:
                n_in = X.shape[1]
            else:
                n_in = self.hidden_layer_sizes[layer_idx-1]
            n_out = self.hidden_layer_sizes[layer_idx]
            limit = np.sqrt(6 / (n_in + n_out))
            self._w.append(np.random.uniform(-limit, limit, size=(n_in, n_out)))
            self._b.append(0.0)
            
        n_in = self.hidden_layer_sizes[-1]
        n_out = 1
        limit = np.sqrt(6 / (n_in + n_out))
        self._w.append(np.random.uniform(-limit, limit, size=(n_in, n_out)))
        self._b.append(0.0)
        
        assert self._w.shape == 
        
        for epoch in range(num_epochs):
            lin_activ_caches = []
            A = X
            for l in range(0, len(self._w)):
                A_prev = A
                Z = np.dot(self._w[l])
                
            
    def predict(self, X):
                
        return y_prediction
CustomMLPRegressor(hidden_layer_sizes=(100, 50, 30)).fit(df.drop('Price', axis=1), df['Price'])
# Out:
# (50, 100)
# (100, 50)
# (50, 30)
# (30, 1)
#
# 4

# %%
df = pd.read_csv('./data/merged_data.csv')
df
# Out:
#                PC1         PC2        PC3       PC4       PC5       PC6  \
# 0      3419.910843 -483.031634  -3.398608 -8.042770  0.889019 -0.042800
# 1      3418.057577 -529.667754 -74.964367 -8.016888  1.210881 -1.016772
# 2      3417.398766 -550.991589  -3.760897 -7.938391 -0.310455 -1.540416
# 3      3415.924478 -590.953266  -2.385884 -7.890959 -0.673569 -0.564996
# 4      3416.864768 -565.055814 -11.628935 -7.854109 -1.311513  0.115066
# ...            ...         ...        ...       ...       ...       ...
# 13575    65.828417   91.206501  -1.484890  6.472355 -1.149423 -0.359331
# 13576  1065.322187 -265.102730 -18.340277 -3.642960 -0.807924  0.345274
# 13577  1069.162884 -162.010063  -1.306025 -3.571541 -1.523567  2.160139
# 13578  1085.047682  267.733818   0.664296 -3.473803 -2.785716  2.664701
# 13579   903.458782 -230.299483 -39.315466 -3.571025 -1.338708 -1.043221
#
#             PC7       PC8       PC9      PC10  ...      PC42      PC43  \
# 0      0.069389 -1.040899 -0.446999  0.349008  ... -0.102600 -0.131898
# 1      0.293009 -1.000364 -0.090151  0.677045  ...  0.160192 -0.274086
# 2     -1.013147  0.052738  1.006280  0.322419  ... -0.324849 -0.028676
# 3     -1.109222  0.037534  0.575173  0.043186  ... -0.315747  0.032302
# 4      0.119118 -1.080552  0.535839  0.053610  ... -0.076446 -0.176867
# ...         ...       ...       ...       ...  ...       ...       ...
# 13575 -0.486444  0.078073 -0.100180  0.320790  ...  0.209279  0.568324
# 13576 -0.822266  0.163939  0.953571 -0.572552  ...  0.169483  0.033905
# 13577 -0.885439 -0.126838  0.013415  0.099936  ...  0.148792  0.022132
# 13578 -0.975002 -0.466211  0.375389 -1.037217  ...  0.125811  0.000796
# 13579 -0.939294 -0.238617  0.537235 -1.165972  ...  0.128112 -0.041220
#
#            PC44      PC45      PC46      PC47      PC48      PC49      PC50  \
# 0     -0.328820 -0.041014 -0.039966 -0.318119  0.080555  0.020365  0.163390
# 1     -0.438961  0.651436 -0.072127 -0.152689  0.343013  0.009713  0.152070
# 2     -0.128211 -0.238444 -0.037352 -0.294030  0.017966  0.009102  0.184914
# 3     -0.186581 -0.295302 -0.010397 -0.252918  0.106299 -0.033317  0.140873
# 4     -0.236986  0.026757 -0.023510 -0.039351 -0.102667 -0.015860 -0.059328
# ...         ...       ...       ...       ...       ...       ...       ...
# 13575  0.000890  0.087701  0.043116 -0.020926 -0.267891 -0.096550  0.442323
# 13576 -0.012523 -0.136206  0.066143 -0.165047 -0.199355  0.015365  0.088398
# 13577  0.006052 -0.175148  0.089852 -0.151903 -0.165522  0.068968  0.047430
# 13578  0.073436 -0.117593  0.121307 -0.171482 -0.240113  0.055094  0.063966
# 13579  0.035957 -0.125833  0.121699 -0.159541 -0.243072  0.079636  0.141727
#
#          Price
# 0      1480000
# 1      1035000
# 2      1465000
# 3       850000
# 4      1600000
# ...        ...
# 13575  1245000
# 13576  1031000
# 13577  1170000
# 13578  2500000
# 13579  1285000
#
# [13580 rows x 51 columns]
